# %% [markdown]
# # Data Exploration: 311 Data - Complaints about Trees
# Exploring 311 Service Request data that was downloaded from NYC Open Data
#
# Filters: 2016 data and Agency = DPR

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
import datetime as dt

# graphics with matplot lib
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.style.use('fivethirtyeight')
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# ### Read in the data, which was downloaded as a csv file, into a pandas dataframe
# * print out the shape (rows,columns) of the dataframe and
# * show the first 5 rows of data.

# %%
sr = pd.read_csv('311_DPR_2016.csv')
print sr.shape
sr.head()
# Out:
# (98611, 53)
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2871: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unique Key            Created Date             Closed Date Agency  \
# 0    32307916  12/31/2015 12:33:49 PM  01/05/2016 11:07:29 AM    DPR
# 1    32307963  12/31/2015 01:16:52 PM  12/31/2015 02:48:06 PM    DPR
# 2    32305787  12/31/2015 11:25:28 AM                     NaN    DPR
# 3    32311393  01/01/2016 07:51:41 PM  01/05/2016 10:29:09 AM    DPR
# 4    32331106  01/04/2016 11:44:10 AM                     NaN    DPR
#
#                           Agency Name           Complaint Type  \
# 0  Department of Parks and Recreation  Maintenance or Facility
# 1  Department of Parks and Recreation             DPR Internal
# 2                                 DPR            Agency Issues
# 3  Department of Parks and Recreation  Maintenance or Facility
# 4  Department of Parks and Recreation                Dead Tree
#
#              Descriptor Location Type  Incident Zip    Incident Address  \
# 0  Structure - Outdoors          Park       11232.0                 NaN
# 1          Aided/Injury          Park       11691.0                 NaN
# 2    New Tree Complaint           NaN           NaN                 NaN
# 3  Structure - Outdoors          Park       11235.0                 NaN
# 4       Dead/Dying Tree        Street       10028.0  144 EAST 84 STREET
#
#       Street Name    Cross Street 1 Cross Street 2 Intersection Street 1  \
# 0             NaN               NaN            NaN                   NaN
# 1             NaN               NaN            NaN                   NaN
# 2             NaN               NaN            NaN                   NaN
# 3             NaN               NaN            NaN                   NaN
# 4  EAST 84 STREET  LEXINGTON AVENUE       3 AVENUE                   NaN
#
#   Intersection Street 2 Address Type          City Landmark  Facility Type  \
# 0                   NaN          NaN      BROOKLYN      NaN            NaN
# 1                   NaN          NaN  FAR ROCKAWAY      NaN            NaN
# 2                   NaN          NaN           NaN      NaN            NaN
# 3                   NaN          NaN      BROOKLYN      NaN            NaN
# 4                   NaN      ADDRESS      NEW YORK      NaN            NaN
#
#        Status                Due Date  \
# 0      Closed  01/14/2016 12:33:49 PM
# 1      Closed  01/14/2016 01:16:52 PM
# 2  Email Sent  01/14/2016 11:31:10 AM
# 3      Closed  01/15/2016 07:51:41 PM
# 4        Open  01/09/2016 11:44:10 AM
#
#                               Resolution Description  \
# 0  The condition was inspected and it was determi...
# 1  The injured person has been transported to a h...
# 2  Your comments have been submitted to the Depar...
# 3  The Department of Parks and Recreation has com...
# 4                                                NaN
#
#   Resolution Action Updated Date Community Board      Borough  \
# 0         01/05/2016 11:07:29 AM     07 BROOKLYN     BROOKLYN
# 1         12/31/2015 02:48:06 PM       14 QUEENS       QUEENS
# 2                            NaN   0 Unspecified  Unspecified
# 3         01/05/2016 10:29:09 AM     18 BROOKLYN     BROOKLYN
# 4                            NaN    08 MANHATTAN    MANHATTAN
#
#    X Coordinate (State Plane)  Y Coordinate (State Plane)  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                    996390.0                    222730.0
#
#      Park Facility Name Park Borough           School Name School Number  \
# 0           Sunset Park     BROOKLYN           Sunset Park          B087
# 1  Grassmere Playground       QUEENS  Grassmere Playground          Q353
# 2           Unspecified  Unspecified           Unspecified   Unspecified
# 3     Lenape Playground     BROOKLYN     Lenape Playground       B057-04
# 4           Unspecified    MANHATTAN           Unspecified   Unspecified
#
#   School Region  School Code School Phone Number  \
# 0           NaN          NaN          7189658900
# 1           NaN          NaN          7185205900
# 2   Unspecified  Unspecified         Unspecified
# 3           NaN          NaN          7189658900
# 4   Unspecified  Unspecified         Unspecified
#
#                              School Address   School City School State  \
# 0  41st to 44th Streets, 5th to 7th Avenues      BROOKLYN           NY
# 1   Grassmere Terrace and Brookhaven Avenue  FAR ROCKAWAY           NY
# 2                               Unspecified   Unspecified  Unspecified
# 3    South of Avenue U and East 38th Street      BROOKLYN           NY
# 4                               Unspecified   Unspecified  Unspecified
#
#     School Zip School Not Found  School or Citywide Complaint  Vehicle Type  \
# 0        11232                N                           NaN           NaN
# 1        11691              NaN                           NaN           NaN
# 2  Unspecified                N                           NaN           NaN
# 3        11235                N                           NaN           NaN
# 4  Unspecified                N                           NaN           NaN
#
#    Taxi Company Borough  Taxi Pick Up Location  Bridge Highway Name  \
# 0                   NaN                    NaN                  NaN
# 1                   NaN                    NaN                  NaN
# 2                   NaN                    NaN                  NaN
# 3                   NaN                    NaN                  NaN
# 4                   NaN                    NaN                  NaN
#
#    Bridge Highway Direction  Road Ramp  Bridge Highway Segment  \
# 0                       NaN        NaN                     NaN
# 1                       NaN        NaN                     NaN
# 2                       NaN        NaN                     NaN
# 3                       NaN        NaN                     NaN
# 4                       NaN        NaN                     NaN
#
#    Garage Lot Name  Ferry Direction  Ferry Terminal Name  Latitude  Longitude  \
# 0              NaN              NaN                  NaN       NaN        NaN
# 1              NaN              NaN                  NaN       NaN        NaN
# 2              NaN              NaN                  NaN       NaN        NaN
# 3              NaN              NaN                  NaN       NaN        NaN
# 4              NaN              NaN                  NaN  40.77801 -73.956166
#
#                                    Location
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4  (40.778010340665475, -73.95616637915529)

# %% [markdown]
# Let's take the transpose, so it's easier to see the columns

# %%
sr.head().T
# Out:
#                                                                                 0  \
# Unique Key                                                               32307916
# Created Date                                               12/31/2015 12:33:49 PM
# Closed Date                                                01/05/2016 11:07:29 AM
# Agency                                                                        DPR
# Agency Name                                    Department of Parks and Recreation
# Complaint Type                                            Maintenance or Facility
# Descriptor                                                   Structure - Outdoors
# Location Type                                                                Park
# Incident Zip                                                                11232
# Incident Address                                                              NaN
# Street Name                                                                   NaN
# Cross Street 1                                                                NaN
# Cross Street 2                                                                NaN
# Intersection Street 1                                                         NaN
# Intersection Street 2                                                         NaN
# Address Type                                                                  NaN
# City                                                                     BROOKLYN
# Landmark                                                                      NaN
# Facility Type                                                                 NaN
# Status                                                                     Closed
# Due Date                                                   01/14/2016 12:33:49 PM
# Resolution Description          The condition was inspected and it was determi...
# Resolution Action Updated Date                             01/05/2016 11:07:29 AM
# Community Board                                                       07 BROOKLYN
# Borough                                                                  BROOKLYN
# X Coordinate (State Plane)                                                    NaN
# Y Coordinate (State Plane)                                                    NaN
# Park Facility Name                                                    Sunset Park
# Park Borough                                                             BROOKLYN
# School Name                                                           Sunset Park
# School Number                                                                B087
# School Region                                                                 NaN
# School Code                                                                   NaN
# School Phone Number                                                    7189658900
# School Address                           41st to 44th Streets, 5th to 7th Avenues
# School City                                                              BROOKLYN
# School State                                                                   NY
# School Zip                                                                  11232
# School Not Found                                                                N
# School or Citywide Complaint                                                  NaN
# Vehicle Type                                                                  NaN
# Taxi Company Borough                                                          NaN
# Taxi Pick Up Location                                                         NaN
# Bridge Highway Name                                                           NaN
# Bridge Highway Direction                                                      NaN
# Road Ramp                                                                     NaN
# Bridge Highway Segment                                                        NaN
# Garage Lot Name                                                               NaN
# Ferry Direction                                                               NaN
# Ferry Terminal Name                                                           NaN
# Latitude                                                                      NaN
# Longitude                                                                     NaN
# Location                                                                      NaN
#
#                                                                                 1  \
# Unique Key                                                               32307963
# Created Date                                               12/31/2015 01:16:52 PM
# Closed Date                                                12/31/2015 02:48:06 PM
# Agency                                                                        DPR
# Agency Name                                    Department of Parks and Recreation
# Complaint Type                                                       DPR Internal
# Descriptor                                                           Aided/Injury
# Location Type                                                                Park
# Incident Zip                                                                11691
# Incident Address                                                              NaN
# Street Name                                                                   NaN
# Cross Street 1                                                                NaN
# Cross Street 2                                                                NaN
# Intersection Street 1                                                         NaN
# Intersection Street 2                                                         NaN
# Address Type                                                                  NaN
# City                                                                 FAR ROCKAWAY
# Landmark                                                                      NaN
# Facility Type                                                                 NaN
# Status                                                                     Closed
# Due Date                                                   01/14/2016 01:16:52 PM
# Resolution Description          The injured person has been transported to a h...
# Resolution Action Updated Date                             12/31/2015 02:48:06 PM
# Community Board                                                         14 QUEENS
# Borough                                                                    QUEENS
# X Coordinate (State Plane)                                                    NaN
# Y Coordinate (State Plane)                                                    NaN
# Park Facility Name                                           Grassmere Playground
# Park Borough                                                               QUEENS
# School Name                                                  Grassmere Playground
# School Number                                                                Q353
# School Region                                                                 NaN
# School Code                                                                   NaN
# School Phone Number                                                    7185205900
# School Address                            Grassmere Terrace and Brookhaven Avenue
# School City                                                          FAR ROCKAWAY
# School State                                                                   NY
# School Zip                                                                  11691
# School Not Found                                                              NaN
# School or Citywide Complaint                                                  NaN
# Vehicle Type                                                                  NaN
# Taxi Company Borough                                                          NaN
# Taxi Pick Up Location                                                         NaN
# Bridge Highway Name                                                           NaN
# Bridge Highway Direction                                                      NaN
# Road Ramp                                                                     NaN
# Bridge Highway Segment                                                        NaN
# Garage Lot Name                                                               NaN
# Ferry Direction                                                               NaN
# Ferry Terminal Name                                                           NaN
# Latitude                                                                      NaN
# Longitude                                                                     NaN
# Location                                                                      NaN
#
#                                                                                 2  \
# Unique Key                                                               32305787
# Created Date                                               12/31/2015 11:25:28 AM
# Closed Date                                                                   NaN
# Agency                                                                        DPR
# Agency Name                                                                   DPR
# Complaint Type                                                      Agency Issues
# Descriptor                                                     New Tree Complaint
# Location Type                                                                 NaN
# Incident Zip                                                                  NaN
# Incident Address                                                              NaN
# Street Name                                                                   NaN
# Cross Street 1                                                                NaN
# Cross Street 2                                                                NaN
# Intersection Street 1                                                         NaN
# Intersection Street 2                                                         NaN
# Address Type                                                                  NaN
# City                                                                          NaN
# Landmark                                                                      NaN
# Facility Type                                                                 NaN
# Status                                                                 Email Sent
# Due Date                                                   01/14/2016 11:31:10 AM
# Resolution Description          Your comments have been submitted to the Depar...
# Resolution Action Updated Date                                                NaN
# Community Board                                                     0 Unspecified
# Borough                                                               Unspecified
# X Coordinate (State Plane)                                                    NaN
# Y Coordinate (State Plane)                                                    NaN
# Park Facility Name                                                    Unspecified
# Park Borough                                                          Unspecified
# School Name                                                           Unspecified
# School Number                                                         Unspecified
# School Region                                                         Unspecified
# School Code                                                           Unspecified
# School Phone Number                                                   Unspecified
# School Address                                                        Unspecified
# School City                                                           Unspecified
# School State                                                          Unspecified
# School Zip                                                            Unspecified
# School Not Found                                                                N
# School or Citywide Complaint                                                  NaN
# Vehicle Type                                                                  NaN
# Taxi Company Borough                                                          NaN
# Taxi Pick Up Location                                                         NaN
# Bridge Highway Name                                                           NaN
# Bridge Highway Direction                                                      NaN
# Road Ramp                                                                     NaN
# Bridge Highway Segment                                                        NaN
# Garage Lot Name                                                               NaN
# Ferry Direction                                                               NaN
# Ferry Terminal Name                                                           NaN
# Latitude                                                                      NaN
# Longitude                                                                     NaN
# Location                                                                      NaN
#
#                                                                                 3  \
# Unique Key                                                               32311393
# Created Date                                               01/01/2016 07:51:41 PM
# Closed Date                                                01/05/2016 10:29:09 AM
# Agency                                                                        DPR
# Agency Name                                    Department of Parks and Recreation
# Complaint Type                                            Maintenance or Facility
# Descriptor                                                   Structure - Outdoors
# Location Type                                                                Park
# Incident Zip                                                                11235
# Incident Address                                                              NaN
# Street Name                                                                   NaN
# Cross Street 1                                                                NaN
# Cross Street 2                                                                NaN
# Intersection Street 1                                                         NaN
# Intersection Street 2                                                         NaN
# Address Type                                                                  NaN
# City                                                                     BROOKLYN
# Landmark                                                                      NaN
# Facility Type                                                                 NaN
# Status                                                                     Closed
# Due Date                                                   01/15/2016 07:51:41 PM
# Resolution Description          The Department of Parks and Recreation has com...
# Resolution Action Updated Date                             01/05/2016 10:29:09 AM
# Community Board                                                       18 BROOKLYN
# Borough                                                                  BROOKLYN
# X Coordinate (State Plane)                                                    NaN
# Y Coordinate (State Plane)                                                    NaN
# Park Facility Name                                              Lenape Playground
# Park Borough                                                             BROOKLYN
# School Name                                                     Lenape Playground
# School Number                                                             B057-04
# School Region                                                                 NaN
# School Code                                                                   NaN
# School Phone Number                                                    7189658900
# School Address                             South of Avenue U and East 38th Street
# School City                                                              BROOKLYN
# School State                                                                   NY
# School Zip                                                                  11235
# School Not Found                                                                N
# School or Citywide Complaint                                                  NaN
# Vehicle Type                                                                  NaN
# Taxi Company Borough                                                          NaN
# Taxi Pick Up Location                                                         NaN
# Bridge Highway Name                                                           NaN
# Bridge Highway Direction                                                      NaN
# Road Ramp                                                                     NaN
# Bridge Highway Segment                                                        NaN
# Garage Lot Name                                                               NaN
# Ferry Direction                                                               NaN
# Ferry Terminal Name                                                           NaN
# Latitude                                                                      NaN
# Longitude                                                                     NaN
# Location                                                                      NaN
#
#                                                                        4
# Unique Key                                                      32331106
# Created Date                                      01/04/2016 11:44:10 AM
# Closed Date                                                          NaN
# Agency                                                               DPR
# Agency Name                           Department of Parks and Recreation
# Complaint Type                                                 Dead Tree
# Descriptor                                               Dead/Dying Tree
# Location Type                                                     Street
# Incident Zip                                                       10028
# Incident Address                                      144 EAST 84 STREET
# Street Name                                               EAST 84 STREET
# Cross Street 1                                          LEXINGTON AVENUE
# Cross Street 2                                                  3 AVENUE
# Intersection Street 1                                                NaN
# Intersection Street 2                                                NaN
# Address Type                                                     ADDRESS
# City                                                            NEW YORK
# Landmark                                                             NaN
# Facility Type                                                        NaN
# Status                                                              Open
# Due Date                                          01/09/2016 11:44:10 AM
# Resolution Description                                               NaN
# Resolution Action Updated Date                                       NaN
# Community Board                                             08 MANHATTAN
# Borough                                                        MANHATTAN
# X Coordinate (State Plane)                                        996390
# Y Coordinate (State Plane)                                        222730
# Park Facility Name                                           Unspecified
# Park Borough                                                   MANHATTAN
# School Name                                                  Unspecified
# School Number                                                Unspecified
# School Region                                                Unspecified
# School Code                                                  Unspecified
# School Phone Number                                          Unspecified
# School Address                                               Unspecified
# School City                                                  Unspecified
# School State                                                 Unspecified
# School Zip                                                   Unspecified
# School Not Found                                                       N
# School or Citywide Complaint                                         NaN
# Vehicle Type                                                         NaN
# Taxi Company Borough                                                 NaN
# Taxi Pick Up Location                                                NaN
# Bridge Highway Name                                                  NaN
# Bridge Highway Direction                                             NaN
# Road Ramp                                                            NaN
# Bridge Highway Segment                                               NaN
# Garage Lot Name                                                      NaN
# Ferry Direction                                                      NaN
# Ferry Terminal Name                                                  NaN
# Latitude                                                          40.778
# Longitude                                                       -73.9562
# Location                        (40.778010340665475, -73.95616637915529)

# %% [markdown]
# ### What's in the 'Desciptor' column?
# Do a groupby to look at the type of results in that column and sort by number of values, with the most common values listed first.

# %%
sr.groupby('Descriptor').count()[['Unique Key']].sort_values('Unique Key', ascending = False)
# Out:
#                                 Unique Key
# Descriptor
# For One Address                      18347
# Branch or Limb Has Fallen Down       10331
# Planted More Than 2 Years Ago         8873
# Trees and Sidewalks Program           7489
# Structure - Outdoors                  6273
# Branch Cracked and Will Fall          4840
# Hitting Building                      4415
# Entire Tree Has Fallen Down           3712
# Hitting Power/Phone Lines             2776
# Tree Alive - in Poor Condition        2518
# Garbage or Litter                     2490
# Blocking Street                       2236
# Dead Branches in Tree                 2235
# Tree Leaning/Uprooted                 2167
# New Tree Complaint                    1723
# Aided/Injury                          1492
# Planted Less Than 2 Years Ago         1339
# Grass/Weeds                           1178
# Structure - Indoors                   1147
# Rodent Sighting                        844
# Obstructing Public Use                 833
# Dog Off Leash                          772
# Graffiti or Vandalism                  749
# Trunk Damaged                          720
# Branches Damaged                       672
# Unauthorized Tree Removal              636
# Clear Street Light                     613
# Snow or Ice                            604
# Unsecured Facility                     501
# Affecting Sewer or Foundation          487
# ...                                    ...
# Roots Damaged                          473
# Unlicensed Vendors                     410
# Tree Trunk Split                       393
# Smoking                                365
# Dead/Dying Tree                        347
# Traffic Sign or Signal Blocked         343
# Dead Animal                            342
# BBQ Outside Authorized Area            337
# Bicycle Chained to Tree                305
# Injured Wildlife                       258
# Property                               217
# Wildlife Sighting                      174
# Unsafe Use of Playground               172
# Unauthorized Tree Pruning              159
# Broken Glass                           157
# Animal Waste                           128
# Domestic Strays                        103
# Removing Wildlife                      103
# Biking/Rollerblading off Path           70
# Locker Break-in/Incident                58
# Lost/Missing Person                     44
# Sidewalk Consultation                   34
# Illegal Dumping                         29
# Unauthorized Posting of Signs           28
# Use of Newly Seeded Lawn                20
# Unauthorized Film Shoot                 17
# Unauthorized Climbing                   17
# Removing Flowers/Plants                 10
# Beach/Pool Closure                       7
# Loud Talking                             1
#
# [61 rows x 1 columns]

# %% [markdown]
# ### Pick out all the Fallen Tree complaints
# Creating a new dataframe which only has complaints 'Entire Tree Has Fallen Down'
#
# Note: The .copy() is not really necessary (it basically specifies that any changes to 1fallenTree will not affect the source dataframe sr), but without it you get annoying warnings from pandas.

# %%
fallenTree = sr[sr['Descriptor']=='Entire Tree Has Fallen Down'].copy()
fallenTree.shape
# Out:
# (3712, 53)

# %% [markdown]
# ### Date of complaint
# Format the 'Created Date' field into a datetime format, and then drop the time part.

# %%
fallenTree['Created Date'] = pd.to_datetime(fallenTree['Created Date'])
fallenTree['date'] = fallenTree['Created Date'].apply(lambda x:x.strftime('%Y-%m-%d'))

# %% [markdown]
#  ### Plot the frequency counts of the number of complaints per day.

# %%
plt.style.available
# Out:
# [u'seaborn-darkgrid',
#  u'seaborn-notebook',
#  u'seaborn-muted',
#  u'seaborn-ticks',
#  u'grayscale',
#  u'bmh',
#  u'seaborn-talk',
#  u'dark_background',
#  u'ggplot',
#  u'fivethirtyeight',
#  u'seaborn-colorblind',
#  u'seaborn-deep',
#  u'seaborn-whitegrid',
#  u'seaborn-bright',
#  u'seaborn-poster',
#  u'classic',
#  u'seaborn-paper',
#  u'seaborn-white',
#  u'seaborn-pastel',
#  u'seaborn-dark',
#  u'seaborn-dark-palette']

# %%
freq = fallenTree.groupby('date').count()[['Unique Key']]
freq.plot(legend=False, figsize=(15,8))
plt.ylabel('complaints per day')
plt.title('Frequency of Fallen Tree Complaints via 311')

# %% [markdown]
# We see a few spikes in the data, where there are more complaints than usual about fallen trees. Let's look at the dates where there are more than 100 complaints per day.

# %%
freq[freq['Unique Key']>100]
# Out:
#             Unique Key
# date
# 2016-02-25         120
# 2016-04-03         337
# 2016-07-18         190

# %% [markdown]
# Of the three largest spikes, the one on April 3, 2016 is the biggest by far.
#
# Doing a quick google search to see what happened on that day and in particular what the weather was like, I found the following NYT article.

# %% [markdown]
# ![title](nyt_2016-04-03.jpg)

# %% [markdown]
# ###Where to go from here?
# * What happened on the other days with high complaints of fallen trees? Were those also high wind days?
# * Is there a correlation between wind speed and fallen trees?
# * What about temperature? Or change in temperature?
# * What other columns look interestiing and could be further explored?
